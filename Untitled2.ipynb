# %%
def f(x):
    return np.power(x,2)
x2= np.arange(0,10000,1)
y = f(x2)
plt.figure
plt.xlabel("x2")
plt.ylabel("y")
plt.plot(x2, y)

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
